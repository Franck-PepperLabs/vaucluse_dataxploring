# %% [markdown]
# # **Qui sont les élus ?**
#
# Nous nous intéressons ici à constituer un référentiel national le plus complet et actualisé des élus et autres mandataires.
#
# Le point de départ de l'investigation excentrique est de lister toutes les questions du type :
# * qui sont les élus, qui sont les etc ... rôles/fonction - collectivité ou autre personne morale de droit public ou semi-public
#
# Cette zone d'investigation est donc à croiser avec celle des institutions qui permet de comprendre et rendre apparente la super-structure institutionnelle (administrative).

# %% [markdown]
# ## Sources
#
# [Recherche **`maires`** sur Data.gouv](https://www.data.gouv.fr/fr/datasets/?q=maires)
#
# 2402 résultats, dont :

# %% [markdown]
# # Elus
#
# ## Elus locaux
#
# https://www.**collectivites-locales**.gouv.fr/elus-locaux
#
# Les **élus locaux** représentent les **citoyens** des différentes **collectivités territoriales**. Ils sont élus dans le but d'agir pour l’**intérêt local**.
#
# Ils sont **membres** des **organes délibérants** de ces collectivités.
#
# Au 1er janvier 2018, il y a 503 305 **conseillers municipaux**, 4031 **conseillers départementaux** et 1922 **conseillers régionaux**.
#
# Au sommaire de la rubrique
# * Maire
# * Président du conseil départemental
# * Président du conseil régional
# * Statut de l'élu
# * Responsabilité pénale
# * Association d'élus
# * Conseil national de la formation des élus locaux (CNFEL)

# %% [markdown]
# ### Maire
#
# Le **maire** est à la fois **exécutif de la commune** et **agent de l'Etat**. Ces deux **types de fonctions** s'exercent dans des conditions différentes.
#
# Le maire représente la **commune** à l’égard des **tiers**. Il est chargé de *préparer* et d’*exécuter* le **budget** et les **délibérations** du **conseil municipal**. Il peut également être chargé en tout ou partie, de certaines de ses compétences par **délégation** de l’**assemblée délibérante**.
#
# Il est seul chargé de l’**administration municipale**, mais il peut procéder à des **délégations de fonctions ou de signature**.
#
# En outre, le maire est chargé des **pouvoirs de police**.
#
# Le maire exerce ses attributions sous le contrôle du **conseil municipal**, dans le cadre des délégations qui peuvent lui être accordées par ce dernier, et également sous le contrôle du **représentant de l’État dans le département**, puisqu’une grande partie des **actes** qu’il prend sont soumis au **contrôle de légalité**.
#
# S’agissant de ses relations avec le **Préfet**, le maire peut demander à ce dernier les informations nécessaires à l’exercice des attributions de la commune. De même, le préfet peut demander au maire les informations nécessaires à l’exercice de ses attributions (article [L. 2121-40](https://www.legifrance.gouv.fr/codes/article_lc/LEGIARTI000006389908) du CGCT).
#
# Dans le cadre de ses fonctions, le maire agit également en tant qu'**agent de l'Etat**. A ce titre il est notamment chargé de l'**état civil**, de la *révision et de la tenue* des **listes électorales**, de l'*organisation* des **élections** ainsi que du **recensement citoyen**. En outre, il dispose d'attributions spécifiques en matière de **police** et de **sécurité civile**.
#
# Lorsque le maire intervient en tant qu'**agent de l'Etat**, il agit, selon le cas, sous le contrôle de l'**autorité administrative** (**préfet** ou **sous-préfet**) ou **judiciaire** (**procureur de la République**).
#
# Parmi vous, certains ont déjà l’expérience d’un **mandat local**. Pour d’autres, vous allez exercer cette **responsabilité** pour la première fois. Tous, vous êtes les piliers de l’**harmonie sociale**, du **bon fonctionnement** de votre commune et de son **développement**. Tous vous êtes, au quotidien, le **visage et la voix de la République**. C’est une immense responsabilité. [**Le guide du Maire** (660 p)](https://www.collectivites-locales.gouv.fr/files/Institution/4.%20elus%20locaux/guide_du_maire_2020.pdf) a justement été conçu comme un outil d’accompagnement et de conseil à destination des 500 000 **élus municipaux** engagés au service de leurs **administrés**. Il a été réalisé conjointement par le **ministère de la Cohésion des territoires et des Relations avec les collectivités territoriales**, le **ministère de l’Action et des Comptes publics** et le **ministère de l’Intérieur**.

# %% [markdown]
# ### Président du conseil départemental
#
# https://www.collectivites-locales.gouv.fr/institutions/le-president-du-conseil-departemental
#
# Une loi de 1831 prévoit l'élection (au suffrage censitaire) des conseillers généraux. L'exécutif départemental est assuré par le préfet de leur création, par la loi du 28 pluviôse an VIII (17 février 1800), à la loi du 2 mars 1982.
#
# C'est en 1871 que les conseillers généraux sont élus au suffrage universel direct.
#
# Le président constitue l’organe exécutif du département mais peut déléguer l’exercice d’une partie de ses fonctions aux vice-présidents et, dans certaines conditions, à des membres du conseil départemental.
# Ces délégations peuvent être annulées à tout moment.
# Le président du conseil départemental préside la commission permanente composée des vice-présidents et éventuellement d’un ou plusieurs autres membres.
#
# Le nombre de vice-présidents peut varier de quatre à quinze, mais ne peut être supérieur à 30% de l’effectif du conseil.
#
# Cette commission permanente, qui tient ses pouvoirs de l’assemblée délibérante, gère les affaires que lui a déléguées le conseil départemental.
#
# En tant qu’organe exécutif, le président du conseil départemental prépare et exécute les délibérations de l’assemblée délibérante (article L. 3221-1 du CGCT). Il est ainsi l’ordonnateur des dépenses du département et prescrit l’exécution des recettes départementales.
#
# Par ailleurs, en application de l’article L. 3211-2 du CGCT, le conseil départemental peut déléguer à son président certaines compétences.
#
# Enfin, le président gère le domaine du département ce qui lui confère des pouvoirs de police particuliers, notamment en matière de circulation.
#
# #### Election des conseillers départementaux
#
# La [loi n° 2013-403](https://www.legifrance.gouv.fr/loda/id/JORFTEXT000027414225) du 17 mai 2013 décide que les mots : "conseils généraux ", "conseiller général" et "conseillers généraux" sont remplacés, respectivement, par les mots : "conseils départementaux", "conseiller départemental" et "conseillers départementaux".
# Les mots : "conseil général", lorsqu'ils s'appliquent à l'organe mentionné à l'[article L. 3121-1 du code général des collectivités territoriales](https://www.legifrance.gouv.fr/codes/article_lc/LEGIARTI000030185581), sont remplacés par les mots : "conseil départemental".
#
# Les conseillers départementaux sont élus pour six ans ; ils sont rééligibles. Les conseils départementaux se renouvellent intégralement. Les élections ont lieu au mois de mars. Dans tous les départements, les collèges électoraux sont convoqués le même jour.
#
# Les conseillers départementaux seront au nombre de deux par canton, chaque binôme devra être composé d’une femme et d’un homme.
#
# L'article 4 de la loi stipule que "Le nombre de cantons dans lesquels sont élus les conseillers départementaux est égal, pour chaque département, à la moitié du nombre de cantons existant au 1er janvier 2013".
#
# Les conseillers généraux sont élus au suffrage universel direct depuis la [loi départementale du 10 août 1871](https://www.legifrance.gouv.fr/jorf/id/JORFTEXT000000515629).
#
# La circonscription électorale est le canton, une subdivision du département.
#
# Chaque canton élit un conseiller général et nul ne peut être candidat dans plus d’un canton. La durée du mandat des conseillers généraux est fixée à six ans et ceux-ci sont renouvelés par moitié tous les trois ans : une moitié concurremment aux élections municipales, l’autre moitié avec les élections régionales.
#
# Le scrutin est majoritaire uninominal à deux tours.
#
# Ainsi, nul n’est élu au premier tour s’il n’a réuni cumulativement :
#
# * la majorité absolue des suffrages exprimés ;
# * un nombre de suffrages égal au quart des électeurs inscrits.
#
# Au second tour, la majorité relative suffit et le candidat élu sera celui ayant obtenu le plus grand nombre de suffrages. En cas d’égalité de suffrages, le plus âgé remporte les élections.
#
# Dans ce cadre, les seuls candidats ayant obtenu au premier tour un nombre de voix supérieur à 10% des électeurs inscrits peuvent se présenter à ce second tour.
#
# De nombreux cas d’inéligibilité et d’incompatibilité sont prévus afin d’écarter du scrutin les candidats titulaires de charges administratives, militaires, judiciaires ou, plus généralement, de contrôle et d’autorité dans le département.
#
# Lors de la réunion qui suit chaque renouvellement, le conseil général élit son président, et la commission permanente composée de vice-présidents et d’un ou plusieurs autres membres.
#
# La présence d’au moins deux tiers des membres est requise et le président est élu à la majorité absolue pour trois ans (article [L. 3122-1](https://www.legifrance.gouv.fr/codes/article_lc/LEGIARTI000006391609/2013-01-22) du CGCT).
#
# Si cette élection n’est pas acquise après les deux premiers tours de scrutin, il est procédé à un troisième tour et l’élection a alors lieu à la majorité relative des membres du conseil général.
#
# La commission permanente est élue au scrutin de liste, à la représentation proportionnelle pour assurer aux différents groupes politiques leur participation à ses délibérations sur les affaires que lui a déléguées le conseil général.
#
# #### Elections et attributions du président du Conseil départemental
#
# La loi n° 2013-403 du 17 mai 2013 relative à l'élection des conseillers départementaux, des conseillers municipaux et des conseillers communautaires et modifiant le calendrier électoral a instauré d’importantes modifications :
#
# * les conseils généraux et les conseillers généraux sont renommés respectivement conseils départementaux et conseillers départementaux ;
# * les conseils départementaux sont renouvelés dans leur ensemble tous les six ans, et non plus par moitié en deux séries ;
# * les conseillers départementaux sont désormais élus au scrutin binominal mixte majoritaire à deux tours : deux conseillers départementaux de sexe différent formant un binôme sont élus dans chaque canton au scrutin majoritaire à deux tours.
#
#
#
# Le conseil départemental élit son président, ainsi que les autres membres de la commission permanente lors de la réunion de droit qui suit le renouvellement général en application de l’article L. 3122-1 du code général des collectivités territoriales (CGCT).
#
# Tous les conseillers départementaux en exercice sont éligibles aux fonctions de président mais cette fonction est incompatible avec certains autres mandats (président d’un conseil régional, maire, membre de la commission européenne, exercice d’un mandat parlementaire…).
#
# Deux tiers des membres doivent être présents pour procéder à l’élection du président.
#
# Le président est élu à la majorité absolue des membres du conseil départemental pour une durée de six ans (dernier alinéa de l’article L. 3122-1 précité). Si cette élection n’est pas acquise après les deux premiers tours du scrutin, il est procédé à un troisième tour de scrutin et l’élection a lieu à la majorité relative des membres du conseil départemental. En cas d’égalité des voix, l’élection est acquise au bénéfice de l’âge.
#
# Le président du conseil départemental est l'organe exécutif du département. Il prépare et exécute les délibérations du conseil départemental.
#
# Il est l'ordonnateur des dépenses du département et prescrit l'exécution des recettes départementales, sous réserve des dispositions particulières du code général des impôts relatives au recouvrement des recettes fiscales des collectivités locales (article L. 3221-2 du CGCT).
#
# Il impute en section d'investissement les dépenses d'équipement afférentes à des biens meubles ne figurant pas sur les listes et d'une valeur inférieure à un seuil fixés par arrêté des ministres en charge des finances et des collectivités locales, sur délibérations expresses de l'assemblée.
#
# Le président du conseil départemental est seul chargé de l'administration. Il peut déléguer par arrêté, sous sa surveillance et sa responsabilité, l'exercice d'une partie de ses fonctions aux vice-présidents. Il peut également déléguer une partie de ses fonctions, dans les mêmes conditions, à des membres du conseil départemental en l'absence ou en cas d'empêchement des vice-présidents ou dès lors que ceux-ci sont tous titulaires d'une délégation. Ces délégations subsistent tant qu'elles ne sont pas rapportées (article L. 3221-3 du CGCT).
#
# Le membre du conseil départemental qui a cessé ses fonctions de président du conseil départemental en application des articles L. 2122-4 ou L. 4133-3 ne peut recevoir de délégation jusqu'au terme de son mandat de conseiller départemental ou jusqu'à la cessation de la fonction l'ayant placé en situation d'incompatibilité.
#
# Le président du conseil départemental est le chef des services du département. Il peut, sous sa surveillance et sa responsabilité, donner délégation de signature en toute matière aux responsables desdits services.
#
# Le président du conseil départemental déclaré comptable de fait par un jugement du juge des comptes statuant définitivement est suspendu de sa qualité d'ordonnateur jusqu'à ce qu'il ait reçu quitus de sa gestion. Dans ce cas, le conseil départemental délibère afin de confier à un vice-président les attributions mentionnées à l'article L. 3221-2. Cette fonction prend fin dès lors que le président du conseil départemental a reçu quitus de sa gestion (article L. 3221-3-1 du CGCT).
#
# Le président du conseil départemental gère le domaine du département. A ce titre, il exerce les pouvoirs de police afférents à cette gestion, notamment en ce qui concerne la circulation sur ce domaine, sous réserve des attributions dévolues aux maires par le présent code et au représentant de l'Etat dans le département ainsi que du pouvoir de substitution du représentant de l'Etat dans le département prévu à l'article L. 3221-5 (article L. 3221-4 du CGCT).
#
# Le représentant de l'Etat dans le département peut, dans le cas où il n'y aurait pas été pourvu par le président du conseil départemental, et après une mise en demeure restée sans résultat, exercer les attributions dévolues au président du conseil départemental en matière de police en vertu des dispositions de l'article L. 3221-4 (article L. 3221-5 du CGCT).
#
# Le président du conseil départemental procède à la désignation des membres du conseil départemental pour siéger au sein d'organismes extérieurs dans les cas et conditions prévus par les dispositions régissant ces organismes. La fixation par les dispositions précitées de la durée des fonctions assignées à ces membres ne fait pas obstacle à ce qu'il puisse être procédé à tout moment, et pour le reste de cette durée, à leur remplacement par une nouvelle désignation opérée dans les mêmes formes (article L. 3221-7 du CGCT).
#
# Le président du conseil départemental procède à la nomination des gardes champêtres dans le cas et les conditions prévus à l'article L. 522-2 du code de la sécurité intérieure (article L. 3221-8 du CGCT).
#
# Il exerce en matière d'action sociale les compétences qui lui sont dévolues par le code de l'action sociale et des familles (article L. 3221-9 du CGCT).
#
# En vue d'exercer la compétence définie par l'article L. 222-4-1 du même code, le président du conseil départemental est informé par le procureur de la République des mesures alternatives aux poursuites et des jugements devenus définitifs lorsque ces décisions concernent des infractions commises par des mineurs résidant sur le territoire du département.
#
# Le président du conseil départemental peut faire tous actes conservatoires et interruptifs de déchéance. Il peut toujours, à titre conservatoire, accepter les dons et legs. La décision du conseil départemental, qui intervient ensuite en application de l'article L. 3213-6, a effet du jour de cette acceptation (article L. 3221-10 du CGCT).
#
# Le président du conseil départemental intente les actions au nom du département en vertu de la décision du conseil départemental et il peut, sur l'avis conforme de la commission permanente, défendre à toute action intentée contre le département. Il peut, par délégation du conseil départemental, être chargé pour la durée de son mandat d'intenter au nom du département les actions en justice ou de défendre le département dans les actions intentées contre lui, dans les cas définis par le conseil départemental. Il rend compte à la plus proche réunion du conseil départemental de l'exercice de cette compétence (article L. 3221-10-1).
#
# Le président, par délégation du conseil départemental, peut être chargé, pour la durée de son mandat, de prendre toute décision concernant la préparation, la passation, l'exécution et le règlement des marchés et des accords-cadres, ainsi que toute décision concernant leurs avenants, lorsque les crédits sont inscrits au budget (article L. 3221-11 du CGCT).
#
# Le président du conseil départemental rend compte à la plus proche réunion utile du conseil départemental de l'exercice de cette compétence et en informe la commission permanente.
#
# Lorsqu'il n'est pas fait application de l'article L. 3221-11, la délibération du conseil départemental ou de la commission permanente chargeant le président du conseil départemental de souscrire un marché ou un accord-cadre déterminé peut être prise avant l'engagement de la procédure de passation de ce marché ou de cet accord-cadre. Elle comporte alors obligatoirement la définition de l'étendue du besoin à satisfaire et le montant prévisionnel du marché ou de cet accord-cadre.
#
# Le président du conseil départemental peut, par délégation du conseil départemental, être chargé d'exercer, au nom du département, les droits de préemption dont celui-ci est titulaire ou délégataire en application du code de l'urbanisme. Il peut également déléguer l'exercice de ce droit à l'occasion de l'aliénation d'un bien, dans les conditions que fixe le conseil départemental. Il rend compte à la plus proche réunion utile du conseil départemental de l'exercice de cette compétence (article L. 3221-12 du CGCT).
#
# Le président du conseil départemental peut, par délégation du conseil départemental, être chargé de prendre toute décision relative au fonds de solidarité pour le logement, notamment en matière d'aides, de prêts, de remises de dettes et d'abandons de créances. Il rend compte à la plus proche réunion utile du conseil départemental de l'exercice de cette compétence (article L. 3221-12-1 du CGCT).
#
# Sauf disposition contraire dans la délibération portant délégation, le président peut subdéléguer les attributions confiées par le conseil départemental dans les conditions prévues par l'article L. 3221-3 (article L. 3221-13 du CGCT).

# %% [markdown]
# # [Répertoire national des élus (RNE)](https://www.data.gouv.fr/fr/datasets/repertoire-national-des-elus-1)
#
# Information sur le jeu de données :
# * **Editeur** : ...
# * **Mise à jour** : 13 septembre 2022
# * **Licence** : [Licence Ouverte / Open Licence](https://www.etalab.gouv.fr/wp-content/uploads/2014/05/Licence_Ouverte.pdf)
# * **Organisation** : [Ministère de l'Intérieur et des Outre-Mer](https://www.data.gouv.fr/fr/organizations/ministere-de-linterieur-et-des-outre-mer/)
# * **Source** :
#     * ...
# * **API** : ...
# * **Thématiques**
#     * ...
# * **Utilisation**
#     * ... DL
#     * .. réutilisations
#     * .. abonnés
#     * .. vues
#
# Le Répertoire National des Élus (RNE) a pour finalité le suivi des titulaires d’un mandat électoral. Il est renseigné et tenu à jour par les préfectures et hauts commissariats et par les services du ministère de l'intérieur, notamment sur la base des éléments fournis par les élus lors de la phase d’enregistrement des candidatures.
#
# Les données du RNE sont structurées par mandat. Neuf fichiers sont publiés ici :
#
# 1. les conseillers municipaux ;
# 2. les conseillers communautaires ;
# 3. les conseillers départementaux ;
# 4. les conseillers régionaux ;
# 5. les membres des assemblées des collectivités à statut particulier ;
# 6. les représentants au Parlement européen ;
# 7. les sénateurs ;
# 8. les députés ;
# 9. les maires.
#
# Un élu qui dispose de plusieurs mandats figurera dans plusieurs fichiers. Un élu qui dispose de plusieurs fonctions apparaitra plusieurs fois au sein du même fichier (exemple : un élu adjoint au maire et maire délégué apparaitra deux fois au sein du fichier des conseillers municipaux).
#
# Les fichiers mis en ligne sont actualisés trimestriellement.
#
# Les données relatives à la profession sont déclaratives. Le référentiel des codes professions correspond au référentiel de l'INSEE.
#
# Les demandes de rectification doivent être adressées directement par courriel à la préfecture territorialement compétente (pref-rne-contact@nom-du-departement.gouv.fr). Aucune demande de rectification adressée sur la plateforme www.data.gouv.fr ne sera prise en compte. Les rectifications apportées dans le RNE ne seront pas reportées immédiatement sur la plate-forme www.data.gouv.fr, mais seront prises en compte pour la publication suivante.

# %% [markdown]
# ## 348 sénateurs

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-sen.csv'
sen = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(sen)
# Out:
#     Code du département Libellé du département  \
# 0                    01                    Ain
# 1                    01                    Ain
# 2                    01                    Ain
# 3                    02                  Aisne
# 4                    02                  Aisne
# ..                  ...                    ...
# 343                 NaN                    NaN
# 344                 NaN                    NaN
# 345                 NaN                    NaN
# 346                 NaN                    NaN
# 347                 NaN                    NaN
#
#     Code de la collectivité à statut particulier  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# ...

# %% [markdown]
# ## 4049 conseillers départementaux

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-cd.csv'
cd = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(cd)
# Out:
#      Code du département Libellé du département Code du canton  \
# 0                     01                    Ain           0101
# 1                     01                    Ain           0101
# 2                     01                    Ain           0102
# 3                     01                    Ain           0102
# 4                     01                    Ain           0103
# ...                  ...                    ...            ...
# 4044                 976                Mayotte          97612
# 4045                 976                Mayotte          97612
# 4046                 976                Mayotte          97612
# 4047                 976                Mayotte          97613
# 4048                 976                Mayotte          97613
#
#       Libellé du canton Nom de l'élu Prénom de l'élu Code sexe  \
# 0     Ambérieu-En-Bugey       BRUNET            Joël         M
# 1     Ambérieu-En-Bugey        PETIT         Aurélie         F
# ...

# %% [markdown]
# ## 500 179 conseillers municipaux

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-cm.csv'
cm = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(cm)
# Out:
#        Code du département Libellé du département  \
# 0                       32                   Gers
# 1                       32                   Gers
# 2                       32                   Gers
# 3                       32                   Gers
# 4                       32                   Gers
# ...                    ...                    ...
# 500174                  32                   Gers
# 500175                  32                   Gers
# 500176                  32                   Gers
# 500177                  32                   Gers
# 500178                  32                   Gers
#
#        Code de la collectivité à statut particulier  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...

# %% [markdown]
# ## 1 750 conseillers régionaux

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-cr.csv'
cr = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(cr)
# Out:
#      Code de la région        Libellé de la région  \
# 0                   01                  Guadeloupe
# 1                   01                  Guadeloupe
# 2                   01                  Guadeloupe
# 3                   01                  Guadeloupe
# 4                   01                  Guadeloupe
# ...                ...                         ...
# 1745                93  Provence-Alpes-Cote D'Azur
# 1746                93  Provence-Alpes-Cote D'Azur
# 1747                93  Provence-Alpes-Cote D'Azur
# 1748                93  Provence-Alpes-Cote D'Azur
# 1749                93  Provence-Alpes-Cote D'Azur
#
#      Code de la section départementale Libellé de la section départementale  \
# 0                                  971                           Guadeloupe
# 1                                  971                           Guadeloupe
# 2                                  971                           Guadeloupe
# ...

# %% [markdown]
# ## 576 députés

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-dep.csv'
dep = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(dep)
# Out:
#     Code du département Libellé du département  \
# 0                    01                    Ain
# 1                    01                    Ain
# 2                    01                    Ain
# 3                    01                    Ain
# 4                    01                    Ain
# ..                  ...                    ...
# 571                 NaN                    NaN
# 572                 NaN                    NaN
# 573                 NaN                    NaN
# 574                 NaN                    NaN
# 575                 NaN                    NaN
#
#     Code de la collectivité à statut particulier  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# ...

# %% [markdown]
# ## 65 684 conseillers communautaires (EPCI)

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-epci.csv'
epci = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(epci)
# Out:
#       Code du département Libellé du département  \
# 0                      01                    Ain
# 1                      01                    Ain
# 2                      01                    Ain
# 3                      01                    Ain
# 4                      01                    Ain
# ...                   ...                    ...
# 65679                 NaN                    NaN
# 65680                 NaN                    NaN
# 65681                 NaN                    NaN
# 65682                 NaN                    NaN
# 65683                 NaN                    NaN
#
#       Code de la collectivité à statut particulier  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# ...

# %% [markdown]
# ## 589 membres des assemblées (des collectivités à statut particulier)

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-ma.csv'
ma = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(ma)
# Out:
#     Code de la région Libellé de la région Code du département  \
# 0                 NaN                  NaN                 NaN
# 1                 NaN                  NaN                 NaN
# 2                 NaN                  NaN                 NaN
# 3                 NaN                  NaN                 NaN
# 4                 NaN                  NaN                 NaN
# ..                ...                  ...                 ...
# 584               NaN                  NaN                 NaN
# 585               NaN                  NaN                 NaN
# 586               NaN                  NaN                 NaN
# 587               NaN                  NaN                 NaN
# 588               NaN                  NaN                 NaN
#
#     Libellé du  département Code de la collectivité à statut particulier  \
# 0                       NaN                                          975
# ...

# %% [markdown]
# ## 34 886 maires

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-maires.csv'
maires = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(maires)
# Out:
#       Code du département Libellé du département  \
# 0                      01                    Ain
# 1                      01                    Ain
# 2                      01                    Ain
# 3                      01                    Ain
# 4                      01                    Ain
# ...                   ...                    ...
# 34881                 NaN                    NaN
# 34882                 NaN                    NaN
# 34883                 NaN                    NaN
# 34884                 NaN                    NaN
# 34885                 NaN                    NaN
#
#       Code de la collectivité à statut particulier  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# ...

# %% [markdown]
# ## 79 représentants au Parlement européen

# %%
import pandas as pd
import numpy as np
base = '../data/min_interieur/rne/'
filename = 'rne-rpe.csv'
rpe = pd.read_csv(base + filename, sep='\t', encoding='utf-8', dtype=object)
display(rpe)
# Out:
#       Nom de l'élu Prénom de l'élu Code sexe Date de naissance  \
# 0          ALFONSI        François         M        14/09/1953
# 1          ANDRIEU            Éric         M        14/04/1960
# 2         ANDROUËT        Mathilde         F        03/07/1984
# 3            AUBRY           Manon         F        22/12/1989
# 4         BARDELLA          Jordan         M        13/09/1995
# ..             ...             ...       ...               ...
# 74       TOUSSAINT           Marie         F        27/05/1987
# 75  TRILLET-LENOIR       Véronique         F        12/06/1957
# 76        VEDRENNE    Marie-Pierre         F        13/12/1982
# 77          YENBOU          Salima         F        14/03/1971
# 78     YON-COURTIN       Stéphanie         F        28/03/1974
#
#    Code de la catégorie socio-professionnelle  \
# 0                                          38
# 1                                         154
# 2                                         120
# ...

# %% [markdown]
# ## Appli 1 : all in one

# %%
ident_cols = ['Nom de l\'élu', 'Prénom de l\'élu', 'Code sexe', 'Date de naissance']
prof_cols = ['Code de la catégorie socio-professionnelle', 'Libellé de la catégorie socio-professionnelle']
mand_cols = ['Date de début du mandat']
merge_cols = ident_cols + prof_cols + mand_cols
lm_col = 'Libellé du mandat'

_sen = sen[merge_cols]
_sen.insert(7, lm_col, 'Sénateur')
display(_sen)

_cd = cd[merge_cols]
_cd.insert(7, lm_col, 'Conseiller départemental')
display(_cd)

_cm = cm[merge_cols]
_cm.insert(7, lm_col, 'Conseiller municipal')
display(_cm)

_cr = cr[merge_cols]
_cr.insert(7, lm_col, 'Conseiller régional')
display(_cr)

_dep = dep[merge_cols]
_dep.insert(7, lm_col, 'Député')
display(_dep)

_epci = epci[merge_cols]
_epci.insert(7, lm_col, 'Conseiller communautaire')
display(_epci)

_ma = ma[merge_cols]
_ma.insert(7, lm_col, 'Membre d\'assemblée')
display(_ma)

_maires = maires[merge_cols]
_maires.insert(7, lm_col, 'Maire')
display(_maires)

_rpe = rpe[merge_cols]
_rpe.insert(7, lm_col, 'Réprésentant au Parlement européen')
display(_rpe)
# Out:
#        Nom de l'élu Prénom de l'élu Code sexe Date de naissance  \
# 0    BLATRIX CONTAT        Florence         F        30/03/1966
# 1            CHAIZE         Patrick         M        22/03/1963
# 2       GOY-CHAVENT          Sylvie         F        23/05/1963
# 3             GRUNY         Pascale         F        18/02/1960
# 4           LEFEVRE         Antoine         M        18/02/1966
# ..              ...             ...       ...               ...
# 343     KULIMOETOKE         Mikaele         M        17/06/1963
# 344      ROHFRITSCH            Teva         M        03/02/1975
# 345        TETUANUI            Lana         F        23/02/1970
# 346         FROGIER          Pierre         M        16/11/1950
# 347          POADJA          Gérard         M        30/09/1963
#
#     Code de la catégorie socio-professionnelle  \
# 0                                           34
# 1                                           85
# 2                                           34
# ...

# %% [markdown]
# ### 607 564 mandats

# %%
import pandas as pd
all = pd.concat([_sen, _cd, _cm, _cr, _dep, _epci, _ma, _maires, _rpe], axis=0)
all = all.sort_values(by=['Nom de l\'élu', 'Prénom de l\'élu'])
all = all.reset_index(drop=True)
display(all)
# Out:
#        Nom de l'élu Prénom de l'élu Code sexe Date de naissance  \
# 0                AA         Herenoa         F        23/06/1982
# 1            AABAÏD         Mélissa         F        25/10/1997
# 2           AABIBOU            Sana         F        24/07/1981
# 3           AABIBOU            Sana         F        24/07/1981
# 4               AAD          Haydar         M        29/03/1978
# ...             ...             ...       ...               ...
# 608135       ÖZTÜRK            Emel         F        16/06/1981
# 608136       ÖZTÜRK            Musa         M        05/10/1969
# 608137       ÖZTÜRK            Musa         M        05/10/1969
# 608138         ÜNLÜ          Lokman         M        15/12/1978
# 608139          NaN       Sourik-Ya         F        14/03/1987
#
#        Code de la catégorie socio-professionnelle  \
# 0                                              22
# 1                                              84
# ...

# %% [markdown]
# ## Appli 2 : cumul de mandats

# %% [markdown]
# ### 501 341 élus

# %%
people = all[all.columns[:4]]
people = people.drop_duplicates()
display(people)
# Out:
#               Nom de l'élu Prénom de l'élu Code sexe Date de naissance
# 0                       AA         Herenoa         F        23/06/1982
# 1                   AABAÏD         Mélissa         F        25/10/1997
# 2                  AABIBOU            Sana         F        24/07/1981
# 4                      AAD          Haydar         M        29/03/1978
# 5       AAD ÉPOUSE SEUGNET           Leila         F        05/11/1976
# ...                    ...             ...       ...               ...
# 608134             ÖZTORUN            Özer         M        05/08/1983
# 608135              ÖZTÜRK            Emel         F        16/06/1981
# 608136              ÖZTÜRK            Musa         M        05/10/1969
# 608138                ÜNLÜ          Lokman         M        15/12/1978
# 608139                 NaN       Sourik-Ya         F        14/03/1987
#
# [501597 rows x 4 columns]

# %% [markdown]
# ### Nombre de mandats par élu

# %%
display(tuple(all[all.columns[:4]].loc[0]))
c = list(all.columns[:4])
a = pd.Series(data=list(zip(all[c[0]], all[c[1]], all[c[2]], all[c[3]])), name='people')
display(a)
# Out:
# ('AA', 'Herenoa', 'F', '23/06/1982')
# 0             (AA, Herenoa, F, 23/06/1982)
# 1         (AABAÏD, Mélissa, F, 25/10/1997)
# 2           (AABIBOU, Sana, F, 24/07/1981)
# 3           (AABIBOU, Sana, F, 24/07/1981)
# 4             (AAD, Haydar, M, 29/03/1978)
#                         ...
# 608135       (ÖZTÜRK, Emel, F, 16/06/1981)
# 608136       (ÖZTÜRK, Musa, M, 05/10/1969)
# 608137       (ÖZTÜRK, Musa, M, 05/10/1969)
# 608138       (ÜNLÜ, Lokman, M, 15/12/1978)
# 608139     (nan, Sourik-Ya, F, 14/03/1987)
# Name: people, Length: 608140, dtype: object

# %%
a_1 = pd.concat([a, pd.Series(data=1, index=a.index, name='#')], axis=1)
gpby = a_1.groupby(by='people').count()
gpby = gpby.sort_values(by='#', ascending=False)
display(gpby.head(30))
# Out:
#                                           #
# people
# (LOUIS, Françoise, F, 30/03/1960)         6
# (GUERIN, Philippe, M, 23/02/1958)         6
# (BONNARD, Colette, F, 11/06/1952)         6
# (DURIX, Arnaud, M, 04/02/1981)            5
# (FONTUGNE, Gilbert, M, 19/08/1951)        5
# (DESQUESNE, Valérie, F, 21/04/1972)       5
# (ANDRÉ, Rémi, M, 20/07/1956)              5
# (LEBEHOT, Jean-Marie, M, 04/06/1966)      5
# (PROVOST, Patrick, M, 21/04/1955)         5
# (GAURAT, Hervé, M, 06/03/1967)            5
# (ASTRUC, Alain, M, 12/03/1953)            5
# (DELEPIERRE, Richard, M, 16/07/1969)      5
# (MORANÇAIS, Patrice, M, 20/08/1961)       5
# (RADENAC, Christelle, F, 01/04/1977)      5
# (PETIT, Bertrand, M, 28/08/1964)          5
# (FOUILLET, Olivier, M, 29/01/1975)        5
# (VERCHERE, Patrice, M, 29/12/1973)        5
# (BOULAY, Florence, F, 26/12/1965)         5
# (CASSIN, Armelle, F, 26/03/1961)          5
# (ROSE, Dominique, M, 07/05/1953)          5
# ...

# %%
print('Nombre d\'élus par nombre de mandats cumulés :')
display(gpby.value_counts())
# Out:
# Nombre d'élus par nombre de mandats cumulés :
# #
# 1    431478
# 2     35865
# 3     32120
# 4      2101
# 5        30
# 6         3
# dtype: int64

# %%
mand_6_people = gpby[gpby['#'] == 6]
display(mand_6_people)
mand_6_index = a[a.isin(mand_6_people.index)].index
display(all.loc[mand_6_index])
# Out:
#                                    #
# people
# (LOUIS, Françoise, F, 30/03/1960)  6
# (GUERIN, Philippe, M, 23/02/1958)  6
# (BONNARD, Colette, F, 11/06/1952)  6
#        Nom de l'élu Prénom de l'élu Code sexe Date de naissance  \
# 65800       BONNARD         Colette         F        11/06/1952
# 65801       BONNARD         Colette         F        11/06/1952
# 65802       BONNARD         Colette         F        11/06/1952
# 65803       BONNARD         Colette         F        11/06/1952
# 65804       BONNARD         Colette         F        11/06/1952
# 65805       BONNARD         Colette         F        11/06/1952
# 279560       GUERIN        Philippe         M        23/02/1958
# 279562       GUERIN        Philippe         M        23/02/1958
# 279563       GUERIN        Philippe         M        23/02/1958
# 279565       GUERIN        Philippe         M        23/02/1958
# 279566       GUERIN        Philippe         M        23/02/1958
# ...

# %%
mand_5_people = gpby[gpby['#'] == 5]
for i in mand_5_people.index:
    print(i)
    mand_5_index = a[a == i].index
    display(all.loc[mand_5_index])
# Out:
# ('DURIX', 'Arnaud', 'M', '04/02/1981')
#        Nom de l'élu Prénom de l'élu Code sexe Date de naissance  \
# 208606        DURIX          Arnaud         M        04/02/1981
# 208607        DURIX          Arnaud         M        04/02/1981
# 208608        DURIX          Arnaud         M        04/02/1981
# 208609        DURIX          Arnaud         M        04/02/1981
# 208610        DURIX          Arnaud         M        04/02/1981
#
#        Code de la catégorie socio-professionnelle  \
# 208606                                         33
# 208607                                         33
# 208608                                         33
# 208609                                         33
# 208610                                         33
#
#        Libellé de la catégorie socio-professionnelle Date de début du mandat  \
# 208606                 Cadre de la fonction publique              01/07/2021
# 208607                 Cadre de la fonction publique              18/05/2020
# ...

# %% [markdown]
# ## Tables dérivées

# %% [markdown]
# ### Table des collectivités

# %% [markdown]
# #### Circonscriptions des sénateurs<br/>108 départements et collectivités à statut particulier

# %%
is_dpt = sen[sen.columns[0]].notna()

code = pd.Series(index=sen.index, name='code', dtype=object)
code[is_dpt] = sen.loc[is_dpt, sen.columns[0]]
code[~is_dpt] = sen.loc[~is_dpt, sen.columns[2]]

lib = pd.Series(index=sen.index, name='libellé', dtype=object)
lib[is_dpt] = sen.loc[is_dpt, sen.columns[1]]
lib[~is_dpt] = sen.loc[~is_dpt, sen.columns[3]]

type = pd.Series(index=sen.index, name='type', dtype=object)
type[is_dpt] = 'DPT'
type[~is_dpt] = 'CSP'

sen_coll = pd.concat([type, code, lib], axis=1)
sen_coll = sen_coll.drop_duplicates()
sen_coll = sen_coll.sort_values(by='code')
sen_coll = sen_coll.reset_index(drop=True)
display(sen_coll)
# Out:
#     type code                          libellé
# 0    DPT   01                              Ain
# 1    DPT   02                            Aisne
# 2    DPT   03                           Allier
# 3    DPT   04          Alpes-De-Haute-Provence
# 4    DPT   05                     Hautes-Alpes
# ..   ...  ...                              ...
# 103  CSP  978                     Saint-Martin
# 104  CSP  986                 Wallis Et Futuna
# 105  CSP  987              Polynésie Française
# 106  CSP  988               Nouvelle-Calédonie
# 107  DPT   ZZ  Français Établis Hors De France
#
# [108 rows x 3 columns]

# %% [markdown]
# #### Circonscriptions des conseillers départementaux<br/>2 028 cantons de 95 départements
#
# https://fr.wikipedia.org/wiki/Canton_français
#
# Les cantons n'ont pas de personalité juridique : ce sont des seulement des circonscriptions administratives.
#
# A la campagne, le canton regroupe plusieurs communes, mais en ville, ce peut être l'inverse.

# %%
type = pd.Series(data='CAN', index=cd.index, name='type', dtype=object)
code = cd[cd.columns[2]].rename('code')
lib = cd[cd.columns[3]].rename('libellé')
type_parent = pd.Series(data='DPT', index=cd.index, name='type_parent', dtype=object)
code_parent = cd[cd.columns[0]].rename('code_parent')
lib_parent = cd[cd.columns[1]].rename('libellé_parent')

cd_can = pd.concat([type, code, lib, type_parent, code_parent, lib_parent], axis=1)
cd_can = cd_can.drop_duplicates()
cd_can = cd_can.sort_values(by='code')
cd_can = cd_can.reset_index(drop=True)
display(cd_can)

cd_dpt = cd_can[cd_can.columns[3:]]
cd_dpt = cd_dpt.drop_duplicates()
cd_dpt = cd_dpt.reset_index(drop=True)
cd_dpt.columns = ['type', 'code', 'libellé']
display(cd_dpt)
# Out:
#      type   code            libellé type_parent code_parent libellé_parent
# 0     CAN   0101  Ambérieu-En-Bugey         DPT          01            Ain
# 1     CAN   0102           Attignat         DPT          01            Ain
# 2     CAN   0103         Valserhône         DPT          01            Ain
# 3     CAN   0104             Belley         DPT          01            Ain
# 4     CAN   0105  Bourg-En-Bresse-1         DPT          01            Ain
# ...   ...    ...                ...         ...         ...            ...
# 2023  CAN  97609          Mtsamboro         DPT         976        Mayotte
# 2024  CAN  97610           Ouangani         DPT         976        Mayotte
# 2025  CAN  97611           Pamandzi         DPT         976        Mayotte
# 2026  CAN  97612               Sada         DPT         976        Mayotte
# 2027  CAN  97613           Tsingoni         DPT         976        Mayotte
#
# [2028 rows x 6 columns]
#    type code                  libellé
# ...

# %% [markdown]
# #### Circonscriptions des conseillers municipaux<br/>35 059 communes de 109 départements et collectivités à statut particulier
#
# https://fr.wikipedia.org/wiki/Commune_(France)

# %%
is_dpt = cm[cm.columns[0]].notna()

code = cm[cm.columns[4]].rename('code')
lib = cm[cm.columns[5]].rename('libellé')
type = pd.Series(data='COM', index=cm.index, name='type', dtype=object)

type_parent = pd.Series(index=cm.index, name='type_parent', dtype=object)
type_parent[is_dpt] = 'DPT'
type_parent[~is_dpt] = 'CSP'

code_parent = pd.Series(index=cm.index, name='code_parent', dtype=object)
code_parent[is_dpt] = cm.loc[is_dpt, cm.columns[0]]
code_parent[~is_dpt] = cm.loc[~is_dpt, cm.columns[2]]

lib_parent = pd.Series(index=cm.index, name='libellé_parent', dtype=object)
lib_parent[is_dpt] = cm.loc[is_dpt, cm.columns[1]]
lib_parent[~is_dpt] = cm.loc[~is_dpt, cm.columns[3]]

cm_com = pd.concat([type, code, lib, type_parent, code_parent, lib_parent], axis=1)
cm_com = cm_com.drop_duplicates()
cm_com = cm_com.sort_values(by='code')
cm_com = cm_com.reset_index(drop=True)
display(cm_com)

cm_dpt = cm_com[cm_com.columns[3:]]
cm_dpt = cm_dpt.drop_duplicates()
cm_dpt = cm_dpt.reset_index(drop=True)
cm_dpt.columns = ['type', 'code', 'libellé']
display(cm_dpt)
# Out:
#       type   code                  libellé type_parent code_parent  \
# 0      COM  01001  L'Abergement-Clémenciat         DPT          01
# 1      COM  01002    L'Abergement-De-Varey         DPT          01
# 2      COM  01004        Ambérieu-En-Bugey         DPT          01
# 3      COM  01005      Ambérieux-En-Dombes         DPT          01
# 4      COM  01006                  Ambléon         DPT          01
# ...    ...    ...                      ...         ...         ...
# 35054  COM  98829                     Thio         CSP         988
# 35055  COM  98830                    Touho         CSP         988
# 35056  COM  98831                      Voh         CSP         988
# 35057  COM  98832                     Yaté         CSP         988
# 35058  COM  98833                  Kouaoua         CSP         988
#
#            libellé_parent
# 0                     Ain
# 1                     Ain
# 2                     Ain
# 3                     Ain
# ...

# %% [markdown]
# #### Circonscriptions des conseillers régionaux = 96 départements de 14 régions
#
# https://fr.wikipedia.org/wiki/Région_française

# %%
type = pd.Series(data='DPT', index=cr.index, name='type', dtype=object)
code = cr[cr.columns[2]].rename('code')
lib = cr[cr.columns[3]].rename('libellé')
type_parent = pd.Series(data='REG', index=cr.index, name='type_parent', dtype=object)
code_parent = cr[cr.columns[0]].rename('code_parent')
lib_parent = cr[cr.columns[1]].rename('libellé_parent')

cr_dpts = pd.concat([type, code, lib, type_parent, code_parent, lib_parent], axis=1)
cr_dpts = cr_dpts.drop_duplicates()
cr_dpts = cr_dpts.sort_values(by='code')
cr_dpts = cr_dpts.reset_index(drop=True)
display(cr_dpts)

cr_reg = cr_dpts[cr_dpts.columns[3:]]
cr_reg = cr_reg.drop_duplicates()
cr_reg = cr_reg.reset_index(drop=True)
cr_reg.columns = ['type', 'code', 'libellé']
display(cr_reg)
# Out:
#    type code                  libellé type_parent code_parent  \
# 0   DPT   01                      Ain         REG          84
# 1   DPT   02                    Aisne         REG          32
# 2   DPT   03                   Allier         REG          84
# 3   DPT   04  Alpes-De-Haute-Provence         REG          93
# 4   DPT   05             Hautes-Alpes         REG          93
# ..  ...  ...                      ...         ...         ...
# 91  DPT   93        Seine-Saint-Denis         REG          11
# 92  DPT   94             Val-De-Marne         REG          11
# 93  DPT   95               Val-D'Oise         REG          11
# 94  DPT  971               Guadeloupe         REG          01
# 95  DPT  974               La Réunion         REG          04
#
#                 libellé_parent
# 0         Auvergne-Rhône-Alpes
# 1              Hauts-De-France
# 2         Auvergne-Rhône-Alpes
# 3   Provence-Alpes-Cote D'Azur
# 4   Provence-Alpes-Cote D'Azur
# ...

# %% [markdown]
# #### Circonscriptions de rattachement des députés<br/>576 circonscriptions législatives de 107 départements
#
# * https://fr.wikipedia.org/wiki/Circonscriptions_législatives_françaises
# * https://fr.wikipedia.org/wiki/Liste_des_circonscriptions_législatives_de_la_France
#
# **Note** - Il en manque une si l'on se réfère à Wikipedia qui en dénombre 577.

# %%
is_dpt = dep[dep.columns[0]].notna()

code = dep[dep.columns[4]].rename('code')
lib = dep[dep.columns[5]].rename('libellé')
type = pd.Series(data='COM', index=dep.index, name='type', dtype=object)

type_parent = pd.Series(index=dep.index, name='type_parent', dtype=object)
type_parent[is_dpt] = 'DPT'
type_parent[~is_dpt] = 'CSP'

code_parent = pd.Series(index=dep.index, name='code_parent', dtype=object)
code_parent[is_dpt] = dep.loc[is_dpt, dep.columns[0]]
code_parent[~is_dpt] = dep.loc[~is_dpt, dep.columns[2]]

lib_parent = pd.Series(index=dep.index, name='libellé_parent', dtype=object)
lib_parent[is_dpt] = dep.loc[is_dpt, dep.columns[1]]
lib_parent[~is_dpt] = dep.loc[~is_dpt, dep.columns[3]]

dep_cl = pd.concat([type, code, lib, type_parent, code_parent, lib_parent], axis=1)
dep_cl = dep_cl.drop_duplicates()
dep_cl = dep_cl.sort_values(by='code')
dep_cl = dep_cl.reset_index(drop=True)
display(dep_cl)

dep_dpt = dep_cl[dep_cl.columns[3:]]
dep_dpt = dep_dpt.drop_duplicates()
dep_dpt = dep_dpt.reset_index(drop=True)
dep_dpt.columns = ['type', 'code', 'libellé']
display(dep_dpt)
# Out:
#     type  code                libellé type_parent code_parent  \
# 0    COM  0101   1Ère Circonscription         DPT          01
# 1    COM  0102   2Ème Circonscription         DPT          01
# 2    COM  0103   3Ème Circonscription         DPT          01
# 3    COM  0104   4Ème Circonscription         DPT          01
# 4    COM  0105   5Ème Circonscription         DPT          01
# ..   ...   ...                    ...         ...         ...
# 571  COM  ZZ07   7Ème Circonscription         DPT          ZZ
# 572  COM  ZZ08   8Ème Circonscription         DPT          ZZ
# 573  COM  ZZ09   9Ème Circonscription         DPT          ZZ
# 574  COM  ZZ10  10Ème Circonscription         DPT          ZZ
# 575  COM  ZZ11  11Ème Circonscription         DPT          ZZ
#
#                       libellé_parent
# 0                                Ain
# 1                                Ain
# 2                                Ain
# 3                                Ain
# ...

# %% [markdown]
# #### Circonscriptions de rattachement des conseillers communautaires<br/>1 272 EPCI de 105 DPT et CSP
#
# https://fr.wikipedia.org/wiki/Établissement_public_de_coopération_intercommunale

# %%
is_dpt = epci[epci.columns[0]].notna()

type = pd.Series(data='EPCI', index=epci.index, name='type', dtype=object)
code = epci[epci.columns[4]].rename('code')
lib = epci[epci.columns[5]].rename('libellé')

type_parent = pd.Series(index=epci.index, name='type_parent', dtype=object)
type_parent[is_dpt] = 'DPT'
type_parent[~is_dpt] = 'CSP'

code_parent = pd.Series(index=epci.index, name='code_parent', dtype=object)
code_parent[is_dpt] = epci.loc[is_dpt, epci.columns[0]]
code_parent[~is_dpt] = epci.loc[~is_dpt, epci.columns[2]]

lib_parent = pd.Series(index=epci.index, name='libellé_parent', dtype=object)
lib_parent[is_dpt] = epci.loc[is_dpt, epci.columns[1]]
lib_parent[~is_dpt] = epci.loc[~is_dpt, epci.columns[3]]

epci_epci = pd.concat([type, code, lib, type_parent, code_parent, lib_parent], axis=1)
epci_epci = epci_epci.drop_duplicates()
epci_epci = epci_epci.sort_values(by='code')
epci_epci = epci_epci.reset_index(drop=True)
display(epci_epci)

epci_dpt = epci_epci[epci_epci.columns[3:]]
epci_dpt = epci_dpt.drop_duplicates()
epci_dpt = epci_dpt.reset_index(drop=True)
epci_dpt.columns = ['type', 'code', 'libellé']
display(epci_dpt)
# Out:
#       type       code                                 libellé type_parent  \
# 0     EPCI  200000172                     Cc Faucigny Glieres         DPT
# 1     EPCI  200000438  Cc Pays Pontchateau St Gildas Des Bois         DPT
# 2     EPCI  200000545      Cc Des Portes De Romilly-Sur-Seine         DPT
# 3     EPCI  200000628           Cc Rhone Lez Provence (Ccrlp)         DPT
# 4     EPCI  200000800                     Cc Coeur De Sologne         DPT
# ...    ...        ...                                     ...         ...
# 1267  EPCI  249740077                                Ca Civis         DPT
# 1268  EPCI  249740085                               Ca Du Sud         DPT
# 1269  EPCI  249740093  Ca Intercommunale Reunion Est (Cirest)         DPT
# 1270  EPCI  249740101    Ca Territoire De La Cote Ouest (Tco)         DPT
# 1271  EPCI  249740119  Ca Intercommunale Nord Reunion (Cinor)         DPT
#
#      code_parent    libellé_parent
# 0             74      Haute-Savoie
# ...
