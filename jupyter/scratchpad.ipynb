# %% [markdown]
# # **Start**
#
# C'est quoi le but ?
#
# Je pars de mon lieu d'habitation, et j'explore excentriquement.
#
# Je veux tout pouvoir connaître du territoire en termes :
# * physiques : géographiques, géologiques, etc
# * d'aménagement : voies de circulation, infrastructures diverses, concentrations urbaines
# * politiques : quels mandats, quelles divisions administratives, quelles juridictions, etc
# * économiques : quelles entreprises et quelles zones d'activité / influence
# * démographiques : quelle population ?
# * etc... tout ce qui peut me passer par la tête et être utile
#
# Sources de données :
# * OpenStreetMap.
# * Wikipedia / wikimedia
# * Data.gouv
# * ...
#
# Outils de webscraping évidemment, car les données ne sont pas toutes assemblées en tableaux.
#
# Penser ce projet comme un socle data à partager entre tous mes projets personnels ayant comme dénominateur commun l'ancrage local. Certains projets donneront lieu à des dépôts publics pour un partage réplicable sur d'autres territoires, d'autres seront trop privés pour être publics^^.

# %% [markdown]
# # Par quoi et par où commencer ? Réflexe data.gouv.fr
#
# Les chiffres de la page d'accueil au 11/12/2022
# * 43 076 Jeux de données
# * 233 308 Ressources
# * 3 317 Réutilisations
# * 100 658 Utilisateurs
# * 3 810 Organisations
# * 11 516 Discussions
#
# ## [À propos : commencer sur data.gouv.fr](https://www.data.gouv.fr/fr/pages/about/a-propos_data-gouv/)
#
# ### Qu’est-ce que data.gouv.fr ?
#
# data.gouv.fr est la plateforme ouverte et communautaire qui vise à centraliser et structurer les données ouvertes en France. Elle favorise la transparence et l’efficacité de l’action publique tout en facilitant la création de nouveaux services.
#
# Sur ce site, vous trouverez des informations sous forme de données numériques brutes. Elles peuvent être téléchargées et utilisées par tous de manière libre et gratuite.
#
# ### À qui s’adresse data.gouv.fr ?
#
# data.gouv.fr est une plateforme communautaire qui s’adresse :
#
# * À celles et ceux qui **produisent des données** (producteurs de données) et qui souhaitent ouvrir leurs données ;
# * À celles et ceux qui **exploitent des données** (réutilisateurs de données) et qui veulent télécharger des données et partager leurs réalisations ;
# * À tout citoyen qui souhaite **découvrir des données** ou trouver une information.
#
# ## Les données ouvertes : qu’est-ce que c’est ?
#
# Les données ouvertes (open data) sont des données en accès libre et gratuit et facilement réutilisables par toutes et tous.
#
# Ces données sont produites par l’administration (ministères, collectivités locales, etc.) mais aussi par des acteurs privés ou encore des citoyens.
#
# Elles portent donc sur des sujets particulièrement variés. Découvrez quelques exemples :
#
# * [**Les données relatives aux élections et aux référendums**](https://www.data.gouv.fr/fr/pages/donnees-des-elections/)
# * [**Les données relatives à la santé**](https://www.data.gouv.fr/fr/pages/donnees-sante/)
# * [**Les données relatives à l'emploi**](https://www.data.gouv.fr/fr/pages/donnees-emploi/)
# * [**Les données relatives aux comptes publics**](https://www.data.gouv.fr/fr/pages/donnees-comptes-publics/)

# %% [markdown]
# ## **Ciblage du Vaucluse**
#
# Une recherche sur [`Vaucluse`](https://www.data.gouv.fr/fr/datasets/?q=Vaucluse) donne 20 résultats, pas véritablement pertinents.
#
# Il va probablement falloir chercher :
# 1. sur des bases à couverture nationale et filtrer.
# 2. sur des bases régionales.

# %% [markdown]
# ## [**Organisation | Région Provence-Alpes-Côte-d'Azur**](https://www.data.gouv.fr/fr/organizations/region-provence-alpes-cote-dazur/)
#
# ### [**Plate-forme open data régionale** (https://www.datasud.fr)](https://www.datasud.fr/)
#
# * 154 Organisations
# * 1 925 Jeux de données
#
# ### Description
#
# Dès 2011, la Région a pris part au vaste mouvement d’ouverture des données publiques pour répondre aux enjeux de transparence, de développement économique et d’innovation par les données.
# Elle a initié une démarche partenariale autour de l’opendata qui s’est traduite par la mise à disposition d’une plateforme régionale accueillant les données de l’institution régionale et celles de collectivités partenaires.
#
# En 2016, la Région a souhaité renforcer ses engagements en votant un nouveau cadre d’intervention et un appel à projets destinés à soutenir la production, la diffusion et l’utilisation des données ouvertes et intelligentes en région Provence-Alpes-Côte d’Azur.
#
# La Région Provence Alpes Côte d'Azur propose depuis mars 2018 une nouvelle plateforme de données, souveraine et mutualisée à l’échelle régionale [DataSud.fr](https://www.datasud.fr/), qui diffuse des données ouvertes, géographiques et intelligentes au service de l’innovation numérique et du développement des territoires.
#
# Depuis mai 2019, le catalogue de données ouvertes de la Région Sud publié sur DataSud.fr est directement intégré et accessible sur Data.Gouv.fr
#
# Site du programme régional des données ouvertes : https://www.dataregionsud.fr/
# @dataregionsud

# %% [markdown]
# ### Catégories
#
# Une première exploration des catégories et jeux de données régionaux montre qu'il faut une méta-cartographie des jeux de données, sans quoi, impossible de s'y retrouver.
#
# ### Thématiques
#
# * Administration et action publique
# * Agriculture, sylviculture et pêche
# * Aménagement et urbanisme
# * Citoyenneté et démocratie
# * Culture, patrimoine et tourisme
# * Economie et entreprises
# * Energies et réseaux
# * Environnement et climat
# * Equipements, bâtiments et logement
# * Formation, éducation et emploi
# * Imagerie et occupation du sol
# * Limites administratives et référentiels
# * Mer, littoral et montagne
# * Mobilité et transports
# * Sciences, recherche et innovation
# * Social, santé et sports
#
# ### Filtres
#
# Sur ciblage Thématique `Administration et action publique`
#
# Organisations :
# * Ville d'Antibes Juan-les-Pins (37)
# * IGN (24)
# * Syndicat Mixte Ouvert SUD THD (20)
# * Communauté d'Agglomération Ventoux Comtat Venaissain (19)
# * Parcs naturels régionaux de Provence-Alpes-Côte d'Azur (19)
# * Région Sud (17)
# * Ville de Digne-les-Bains (15)
# * Conseil départemental de Vaucluse (13)
# * Département des Alpes de Haute-Provence (10)
# * Ville de marseille (10)
# * Ville de Martigues (10)
# * Ville de Nice (10)
# * Communauté de communes du Pays... (7)
# * Conseil départemental des Alpe... (7)
# * Pôle Emploi (7)
# * ARBE Provence-Alpes-Côte d'Azur (5)
# * Département des Hautes-Alpes (05) (5)
# * Ville de Fréjus (5)
# * Avignon (4)
# * Caisse d'allocations familiales (4)
# * Centres Régionaux des Œuvres U... (4)
# * Commune de Roquebrune-sur-Argens (4)
# * Conseil départemental des Bouc... (4)
# * Ministère de l'Enseignement su... (4)
# * Agence nationale de la cohésio... (3)
# * Estérel Côte d'Azur Agglomération (3)
# * Ministère de l'Économie, des F... (3)
# * Ville de Vallauris Golfe-Juan (3)
# * CARIF- OREF Provence Alpes Côt... (2)
# * Communauté d'Agglomération du ... (2)
# * Commune de Châteauneuf-Grasse (2)
# * Durance Luberon Verdon Agglomé... (2)
# * Infogreffe (2)
# * Ministère de l'Éducation natio... (2)
# * Observatoire des finances et d... (2)
# * ADRETS (1)
# * Arsud (1)
# * Communauté de communes du Pays... (1)
# * Communauté de Communes Vallée ... (1)
# * Conseil départemental du Var (1)
# * DDTM 13 (1)
# * DRAAF PACA (1)
# * Dracénie Provence Verdon agglo... (1)
# * Etalab (1)
# * INSEE (1)
# * L'Incassable (1)
# * Ministère de la Transformation... (1)
# * Ministère de la Transition éco... (1)
# * Ministère du Travail, du Plein... (1)
# * Métropole Nice Côte d’Azur (1)
#
# Thématiques de `Administration et action publique` (310 jeux de données) :
# * Aménagement et urbanisme (89)
# * Citoyenneté et démocratie (72)
# * Limites administratives et référentiels (50)
# * Formation, éducation et emploi (44)
# * Economie et entreprises (39)
# * Equipements, bâtiments et logement (35)
# * Social, santé et sports (34)
# * Imagerie et occupation du sol (30)
# * Environnement et climat (29)
# * Culture, patrimoine et tourisme (23)
# * Energie et réseaux (14)
# * Mobilité et transports (14)
# * Mer, littoral et montagne (13)
# * Agriculture, sylviculture et pêche (10)
# * Sciences, recherche et innovation (8)
#
# Granularité (de la couverture territoriale) :
# * Commune (96)
# * Indénie (72)
# * Département (43)
# * Point d'intérêt (POE) (32)
# * Intercommunalité (EPCI) (11)
# * Région (11)
# * Parcelle cadastrale (8)
# * IRIS (quartiers INSEE) (1)
#
# Types :
# * Données ouvertes (269)
# * Données géographiques (115)
# * Données intelligentes (106)
# * Données moissonnées (34)
#
# Fréquence de mise à jour :
# * Lorsque nécessaire (114)
# * Annuelle (82)
# * Inconnue (30)
# * Hebdomadaire (21)
# * Non plannifiée (17)
# * Journalière (15)
# * Mensuelle (9)
# * Trimestrielle (9)
# * Continue (5)
# * semiannual (4)
#
# Mots-clés :
# * budget (26)
# * administration (25)
# * orthophoto (23)
# * orthophotographie (23)
# * EPCI (21)
# * adresse (19)
# * département (19)
# * dépense (19)
# * fibre-optique (19)
# * aménagement du territoire (18)
#
# Licences :
# * Licence Ouverte Version 2.0 (269)
# * Autre Licence (spécifique) (20)
# * Open Data Commons (ODbL) (19)
# * Autre Licence (ouverte) (2)
#
# Supports :
# * Région SUD (113)
#
# Formats :
# * CSV (158)
# * PDF (71)
# * XLSX (56)
# * GeoJSON (55)
# * XLS (53)
# * SHP (50)
# * ZIP (31)
# * HTML (30)
# * JPEG2000 (23)
# * ODS (16)

# %% [markdown]
# ### Quelques exemples

# %% [markdown]
# #### [Registre Parcellaire Graphique (RPG) en Provence Alpes Côte d'Azur](https://trouver.datasud.fr/dataset/groups/registre-parcellaire-graphique-rpg)
#
# Pour ouvrir et visualiser ces données (Shape = SHP) :
# * https://fr.wikipedia.org/wiki/Shapefile
# * https://en.wikipedia.org/wiki/Shapefile
#     * https://github.com/GeospatialPython/pyshp : librairie pour lire et traduire en geoJSON
# * https://fr.wikipedia.org/wiki/GeoJSON
# * https://en.wikipedia.org/wiki/GeoJSON
#
#
# Information sur le jeu de données :
# * **Organisation** : IGN
# * **Source** : https://geoservices.ign.fr/rpg
# * **Thématiques**
#     * Agriculture, sylviculture et pêche
#     * Imagerie et occupation du sol
# * **Utilisation**
#     * 703 DL
#     * 2 réutilisations
#     * 0 abonnés
#     * 0 vues
#
# Base de données géographiques servant de référence à l'instruction des aides de la politique agricole commune (PAC). Ces données sont produites par l'Agence de services et de paiement (ASP) depuis 2007, qui confie à l’IGN la diffusion des données anonymisées du RPG. Ces données fournissent des informations détaillées sur l’occupation du sol et les structures foncières permettant l’identification des parcelles agricoles munies de leur culture principale.
#
# La version anonymisée diffusée dans le cadre du service public de mise à disposition des données de référence contient les données graphiques des parcelles agricoles (depuis 2015) et îlots ( de 2007 à 2014 ).
#
# * l'information sur l'occupation du sol et le type de culture redescend au niveau de la parcelle,
# * l'information sur les structures foncières disparaît.

# %% [markdown]
# #### [**Ville d'Antibes** | Délibérations du conseil municipal](https://trouver.datasud.fr/dataset/deliberations-du-conseil-municipal-a-la-ville-dantibes-juan-les-pins)
#
# Information sur le jeu de données :
# * **Organisation** : Ville d'Antibes Juan-les-Pins
# * **Source** : ...
# * **Thématiques**
#     * Administration et action publique
#     * Aménagement et urbanisme
#     * Citoyenneté et démocratie
#     * Culture, patrimoine et tourisme
#     * Economie et entreprises
#     * Energies et réseaux
#     * Environnement et climat
#     * Equipements, bâtiments et logement
#     * Formation, éducation et emploi
#     * Imagerie et occupation du sol
#     * Mer, littoral et montagne
#     * Mobilité et transports
#     * Sciences, recherche et innovation
#     * Social, santé et sports
# * **Mots clés** : SCDL, actes administratifs, citoyenneté, conseiller municipal, décision, délibération, démocratie, maire, schéma de données publiques
# * **Utilisation**
#     * .. DL
#     * .. réutilisations
#     * .. abonnés
#     * .. vues

# %%
import pandas as pd
antibes = pd.read_csv('../data/antibes/deliberations/antibes_deliberations.csv', dtype=object)
display(antibes)
display(antibes.info())
# Out:
#               COLL_NOM      COLL_SIRET DELIB_ID  DELIB_DATE  \
# 0      Ville d'Antibes  21060004500012      NaN  1869-01-14
# 1      Ville d'Antibes  21060004500012      NaN  1869-01-14
# 2      Ville d'Antibes  21060004500012      NaN  1869-02-07
# 3      Ville d'Antibes  21060004500012      NaN  1869-02-07
# 4      Ville d'Antibes  21060004500012      NaN  1869-02-07
# ...                ...             ...      ...         ...
# 36794  Ville d'Antibes  21060004500012     30-1  2022-11-25
# 36795  Ville d'Antibes  21060004500012     34-1  2022-11-25
# 36796  Ville d'Antibes  21060004500012     34-2  2022-11-25
# 36797  Ville d'Antibes  21060004500012     34-3  2022-11-25
# 36798  Ville d'Antibes  21060004500012     34-4  2022-11-25
#
#       DELIB_MATIERE_CODE                           DELIBE_MATIERE_NOM  \
# 0                    NaN                                          NaN
# 1                    NaN                                          NaN
# ...

# %% [markdown]
# #### [**Département des Alpes de Haute Provence** | Subventions attribuées supérieures à 23000 €](https://trouver.datasud.fr/dataset/subventions-conventionnees-par-le-departement-des-alpes-de-haute-provence)
#
# Information sur le jeu de données :
# * **Organisation** : Département des Alpes de Haute-Provence
# * **Source** : ...
# * **Thématiques**
#     * Administration et action publique
#     * Agriculture, sylviculture et pêche
#     * Culture, patrimoine et tourisme
#     * Economie et entreprises
#     * Environnement et climat
#     * Equipements, bâtiments et logement
#     * Formation, éducation et emploi
#     * Social, santé et sports
# * **Mots clés** : Alpes de Haute Provence, SCDL, association, convention, finances, socle commun données locales, subvention
# * **Utilisation**
#     * 548 DL
#     * .. réutilisations
#     * 0 abonnés
#     * 739 vues
#
#
# Données brutes relatives aux conventions de subventions attribuées par le Département des Alpes de Haute-Provence (04), depuis 2016.
#
# Une convention de subvention est passée lorsque le montant de cette dernière est supérieur à 23 000€. Ce fichier présente toutefois des conventions d'un montant inférieur à ce seuil, dans les cas suivants :
#
#     Conventions relevant de plusieurs services, qui, cumulées pour un même bénéficiaire, atteignent 23 000€.
#     Conventions relevant de la culture, à destination du spectacle vivant (obligation de convention à partir d'1€).
#     Conventions de mise à disposition en nature (locaux, personnel).
#
# La présentation de ces données est normalisée selon le référentiel national "Socle Commun des Données Locales" (SCDL, Open Data France).
#
# Les fichiers téléchargeables en CSV et XML sont mis à jour tous les 3 mois, conformément à l'obligation légale, et contiennent toutes les données depuis 2016. Chaque nouvelle mise à jour vient remplacer l'ancienne. Les statistiques de téléchargements par fichier portent donc sur la période en cours depuis la dernière mise à jour.
#
# NB : Pour tous les rajouts effectués depuis avril 2022, lorsqu'il manque des informations, il y a une explication fournie (fichier XLS). De même lorsque le solde n'a pas encore été réglé.
#
# Cadre légal : cette publication est prise en application de l’article 18 de la loi n°2016-1321 du 7 octobre 2016 pour une République numérique, et conformément au décret n°2017-779 du 5 mai, relatif à l’accès sous forme électronique des données des conventions de subvention, à compter du 1er août 2017.

# %%
import pandas as pd
#C:\Users\franc\Projects\vaucluse_dataxploring\data\dpt_04\subventions
dpt_04 = pd.read_excel(r'../data/dpt_04/subventions/subventionscd04_maj_12-2022_zkbdyj6.xls', dtype=object)
display(dpt_04)
display(dpt_04.info())
# Out:
#                                               COLL_NOM      COLL_SIRET  \
# 0    Conseil départemental des Alpes de Haute-Provence  22040000000000
# 1    Conseil départemental des Alpes de Haute-Provence  22040000000000
# 2    Conseil départemental des Alpes de Haute-Provence  22040000000000
# 3    Conseil départemental des Alpes de Haute-Provence  22040000000000
# 4    Conseil départemental des Alpes de Haute-Provence  22040000000000
# ..                                                 ...             ...
# 352  Conseil départemental des Alpes de Haute-Provence  22040000000000
# 353  Conseil départemental des Alpes de Haute-Provence  22040000000000
# 354  Conseil départemental des Alpes de Haute-Provence  22040000000000
# 355  Conseil départemental des Alpes de Haute-Provence  22040000000000
# 356  Conseil départemental des Alpes de Haute-Provence  22040000000000
#
#     COLL_TYPE            CONV_DATE                 ACTE_REF  \
# ...

# %% [markdown]
# #### Département des Alpes Maritimes | Marchés publics passés
#
# => https://www.departement06.fr/l-information-du-departement/opendata-29882.html
#
# https://trouver.datasud.fr/dataset/marches-publics-passes-par-le-departement-des-alpes-maritimes
#
# Les marchés publics passés par le Département des Alpes-Maritimes depuis fin 2018 d'un montant supérieur à 25 000 € HT. Ces marchés publics sont classés de la date de publication la plus récente à la plus ancienne (mise à jour hebdomadaire)
#
# Deux formats de données sont proposés : csv et xlsx
#
# Les métadonnées sont conformes au modèle de données instauré par Open Data France dans le cadre du Socle Commun des Données Locales pour les marches publics français
#
# La réutilisation de ce jeu de données doit respecter le cadre de la [Licence Ouverte V2.0 d'Etalab](https://www.etalab.gouv.fr/wp-content/uploads/2017/04/ETALAB-Licence-Ouverte-v2.0.pdf)

# %%
# échec de téléchargement : https://datastream.departement06.fr/download/fluxpesmarches/marchesCD06.csv

# %% [markdown]
# #### Ville de Fréjus | Hautes rémunérations
#
# https://trouver.datasud.fr/dataset/hautes-remunerations
#
#
#
# Cette publication entre dans le cadre de l’article 37 de la loi n°2019-828 du 6 août 2019 de transformation de la fonction publique, les régions, les départements, les collectivités territoriales de plus de 80 000 habitants, qui prévoit que les établissements publics de coopération intercommunale à fiscalité propre de plus de 80 000 habitants publient chaque année la somme des dix rémunérations les plus élevées des agents relevant de leur périmètre, en précisant également le nombre de femmes et d'hommes figurant parmi ces dix rémunérations les plus élevées.
#
# Ce jeu de donnée est conforme au schéma de données publiques pour la spécification du fichier de déclaration des dix rémunérations les plus élevées des agents publics.

# %%
import pandas as pd
frejus = pd.read_excel('../data/frejus/hautes_remunerations/tableau-des-10-plus-hautes-remunerations-de-la-ville-de-frejus.xlsx', dtype=object)
display(frejus)
display(frejus.info())
# Out:
#        Siren Dénomination de l'employeur Année  \
# 0  218300614            Mairie de FREJUS  2018
# 1  218300614            Mairie de FREJUS  2019
# 2  218300614            Mairie de FREJUS  2020
# 3  218300614            Mairie de FREJUS  2021
#
#   Somme des 10 plus hautes rémunérations brutes en euros  \
# 0                                          831505.52
# 1                                          782912.78
# 2                                          866300.24
# 3                                          841487.91
#
#   Nombre de femmes bénificiaires Nombre d'hommes bénéficiaires  \
# 0                              4                             6
# 1                              5                             5
# 2                              4                             6
# 3                              3                             7
#
#   Durée cumulée en nombre de mois                       Commentaires
# ...
